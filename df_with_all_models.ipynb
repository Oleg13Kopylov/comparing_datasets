# %% [markdown]
# # В этом ноутбуке мы соберем результаты всех экспериментов в один dataframe. Затем визуализируем их.

# %%
import pandas as pd

df_with_all_models = pd.DataFrame(columns=['accuracy', 'precision', 'recall', 'f1_score'])

# %% [markdown]
# ALBERT

# %%
# albert
df_with_all_models.loc['ALBERT'] = ' ' 
# first
row_name = 'albert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.757868
df_with_all_models.loc[row_name, 'precision'] = 0.83964
df_with_all_models.loc[row_name, 'recall'] = 0.618037
df_with_all_models.loc[row_name, 'f1_score'] =  0.711994
# second
row_name = 'albert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5752
df_with_all_models.loc[row_name, 'precision'] = 0.693416
df_with_all_models.loc[row_name, 'recall'] = 0.2696
df_with_all_models.loc[row_name, 'f1_score'] =  0.388249
# third
row_name = 'albert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.640334
df_with_all_models.loc[row_name, 'precision'] = 0.843972
df_with_all_models.loc[row_name, 'recall'] = 0.31565
df_with_all_models.loc[row_name, 'f1_score'] =  0.459459
# fourth
row_name = 'albert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.695
df_with_all_models.loc[row_name, 'precision'] = 0.68991
df_with_all_models.loc[row_name, 'recall'] = 0.7084
df_with_all_models.loc[row_name, 'f1_score'] =  0.699033

# %% [markdown]
# BERT

# %%
# bert
df_with_all_models.loc['BERT'] = ' ' 
# first
row_name = 'bert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.746735
df_with_all_models.loc[row_name, 'precision'] = 0.706468
df_with_all_models.loc[row_name, 'recall'] = 0.816092
df_with_all_models.loc[row_name, 'f1_score'] =  0.757333
# second
row_name = 'bert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5542
df_with_all_models.loc[row_name, 'precision'] = 0.531071
df_with_all_models.loc[row_name, 'recall'] = 0.9264
df_with_all_models.loc[row_name, 'f1_score'] = 0.67512
# third
row_name = 'bert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.761507
df_with_all_models.loc[row_name, 'precision'] = 0.733333
df_with_all_models.loc[row_name, 'recall'] = 0.797524
df_with_all_models.loc[row_name, 'f1_score'] = 0.764083
# fourth
row_name = 'bert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.6868
df_with_all_models.loc[row_name, 'precision'] = 0.732802
df_with_all_models.loc[row_name, 'recall'] = 0.588
df_with_all_models.loc[row_name, 'f1_score'] =  0.652463

# %% [markdown]
# DistilBERT

# %%
# DistilBERT
df_with_all_models.loc['DistilBERT'] = ' ' 
# first
row_name = 'distilbert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.873261
df_with_all_models.loc[row_name, 'precision'] = 0.900288
df_with_all_models.loc[row_name, 'recall'] = 0.830239
df_with_all_models.loc[row_name, 'f1_score'] = 0.863845
# second
row_name = 'distilbert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7198
df_with_all_models.loc[row_name, 'precision'] = 0.819663
df_with_all_models.loc[row_name, 'recall'] = 0.5636
df_with_all_models.loc[row_name, 'f1_score'] = 0.667931
# third
row_name = 'distilbert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.782916
df_with_all_models.loc[row_name, 'precision'] = 0.695244
df_with_all_models.loc[row_name, 'recall'] = 0.982317
df_with_all_models.loc[row_name, 'f1_score'] = 0.814218
# fourth
row_name = 'distilbert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7728
df_with_all_models.loc[row_name, 'precision'] = 0.803381
df_with_all_models.loc[row_name, 'recall'] = 0.7224
df_with_all_models.loc[row_name, 'f1_score'] = 0.760741

# %% [markdown]
# ELECTRA

# %%
# electra
df_with_all_models.loc['ELECTRA'] = ' ' 
# first
row_name = 'electra trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.776707	
df_with_all_models.loc[row_name, 'precision'] = 0.764425
df_with_all_models.loc[row_name, 'recall'] = 0.778957
df_with_all_models.loc[row_name, 'f1_score'] = 0.771623
# second
row_name = 'electra trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5094
df_with_all_models.loc[row_name, 'precision'] = 0.790123
df_with_all_models.loc[row_name, 'recall'] = 0.0256
df_with_all_models.loc[row_name, 'f1_score'] = 0.049593
# third
row_name = 'electra trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.551916
df_with_all_models.loc[row_name, 'precision'] = 0.520357
df_with_all_models.loc[row_name, 'recall'] = 0.954907
df_with_all_models.loc[row_name, 'f1_score'] = 0.673632
# fourth
row_name = 'electra trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.6996
df_with_all_models.loc[row_name, 'precision'] = 0.664795
df_with_all_models.loc[row_name, 'recall'] = 0.8052
df_with_all_models.loc[row_name, 'f1_score'] = 0.728292

# %% [markdown]
# LaBSE

# %%
# LaBSE
df_with_all_models.loc['LaBSE'] = ' ' 
# first
row_name = 'labse trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.862984
df_with_all_models.loc[row_name, 'precision'] = 0.883633
df_with_all_models.loc[row_name, 'recall'] = 0.825818
df_with_all_models.loc[row_name, 'f1_score'] = 0.853748
# second
row_name = 'labse trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7138
df_with_all_models.loc[row_name, 'precision'] = 0.699515
df_with_all_models.loc[row_name, 'recall'] = 0.7496
df_with_all_models.loc[row_name, 'f1_score'] = 0.723692
# third
row_name = 'labse trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.870263
df_with_all_models.loc[row_name, 'precision'] = 0.916499
df_with_all_models.loc[row_name, 'recall'] = 0.805482
df_with_all_models.loc[row_name, 'f1_score'] = 0.857412
# fourth
row_name = 'labse trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7706
df_with_all_models.loc[row_name, 'precision'] = 0.745198
df_with_all_models.loc[row_name, 'recall'] = 0.8224
df_with_all_models.loc[row_name, 'f1_score'] = 0.781898

# %% [markdown]
# LAMBERT

# %%
# LAMBERT
df_with_all_models.loc['LAMBERT'] = ' ' 
# first
row_name = 'lambert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.792764
df_with_all_models.loc[row_name, 'precision'] = 0.840526
df_with_all_models.loc[row_name, 'recall'] = 0.706012
df_with_all_models.loc[row_name, 'f1_score'] = 0.76742
# second
row_name = 'lambert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5346
df_with_all_models.loc[row_name, 'precision'] = 0.74928
df_with_all_models.loc[row_name, 'recall'] = 0.104
df_with_all_models.loc[row_name, 'f1_score'] = 0.182648
# third
row_name = 'lambert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.674588
df_with_all_models.loc[row_name, 'precision'] = 0.611882
df_with_all_models.loc[row_name, 'recall'] = 0.896994
df_with_all_models.loc[row_name, 'f1_score'] =0.727501
# fourth
row_name = 'lambert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7562
df_with_all_models.loc[row_name, 'precision'] = 0.728017
df_with_all_models.loc[row_name, 'recall'] = 0.818
df_with_all_models.loc[row_name, 'f1_score'] = 0.77039

# %% [markdown]
# MobileBERT

# %%
# MobileBERT
df_with_all_models.loc['MobileBERT'] = ' ' 
# first
row_name = 'mobilebert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.76793
df_with_all_models.loc[row_name, 'precision'] = 0.888011
df_with_all_models.loc[row_name, 'recall'] = 0.595933
df_with_all_models.loc[row_name, 'f1_score'] = 0.713228
# second
row_name = 'mobilebert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5512
df_with_all_models.loc[row_name, 'precision'] = 0.733577
df_with_all_models.loc[row_name, 'recall'] = 0.1608
df_with_all_models.loc[row_name, 'f1_score'] = 0.26378
# third
row_name = 'mobilebert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.510811
df_with_all_models.loc[row_name, 'precision'] = 0.497452
df_with_all_models.loc[row_name, 'recall'] = 0.992485
df_with_all_models.loc[row_name, 'f1_score'] = 0.662731
# fourth
row_name = 'mobilebert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.6444
df_with_all_models.loc[row_name, 'precision'] = 0.61142
df_with_all_models.loc[row_name, 'recall'] = 0.7924
df_with_all_models.loc[row_name, 'f1_score'] = 0.690244

# %% [markdown]
# ROBERTA

# %%
# ROBERTA
df_with_all_models.loc['ROBERTA'] = ' ' 
# first
row_name = 'roberta trained on hotel reviews and tested on hotel reviews dataset	'
df_with_all_models.loc[row_name, 'accuracy'] = 0.925712
df_with_all_models.loc[row_name, 'precision'] = 0.93189
df_with_all_models.loc[row_name, 'recall'] = 0.913351
df_with_all_models.loc[row_name, 'f1_score'] = 0.922527
# second
row_name = 'roberta trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.6938
df_with_all_models.loc[row_name, 'precision'] = 0.879405
df_with_all_models.loc[row_name, 'recall'] = 0.4492
df_with_all_models.loc[row_name, 'f1_score'] = 0.594652
# third
row_name = 'roberta trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.709698
df_with_all_models.loc[row_name, 'precision'] = 0.626184
df_with_all_models.loc[row_name, 'recall'] = 0.993811
df_with_all_models.loc[row_name, 'f1_score'] = 0.768284
# fourth
row_name = 'roberta trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.8378
df_with_all_models.loc[row_name, 'precision'] = 0.837665
df_with_all_models.loc[row_name, 'recall'] = 0.838
df_with_all_models.loc[row_name, 'f1_score'] = 0.837832

# %% [markdown]
# BERT with Talking-Heads Attention and Gated GELU (talkheads_ggelu_bert)

# %%
# BERT with Talking-Heads Attention and Gated GELU (talkheads_ggelu_bert)
df_with_all_models.loc['BERT with Talking-Heads Attention and Gated GELU'] = ' ' 
# first
row_name = 'talkheads_ggelu_bert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.796617	
df_with_all_models.loc[row_name, 'precision'] = 0.843816
df_with_all_models.loc[row_name, 'recall'] = 0.71176
df_with_all_models.loc[row_name, 'f1_score'] = 0.772182
# second
row_name = 'talkheads_ggelu_bert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.5312
df_with_all_models.loc[row_name, 'precision'] = 0.519062
df_with_all_models.loc[row_name, 'recall'] = 0.8496
df_with_all_models.loc[row_name, 'f1_score'] = 0.644417
# third
row_name = 'talkheads_ggelu_bert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.628773
df_with_all_models.loc[row_name, 'precision'] = 0.902439
df_with_all_models.loc[row_name, 'recall'] = 0.261715
df_with_all_models.loc[row_name, 'f1_score'] = 0.405757
# fourth
row_name = 'talkheads_ggelu_bert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.6934
df_with_all_models.loc[row_name, 'precision'] = 0.689831
df_with_all_models.loc[row_name, 'recall'] = 0.7028
df_with_all_models.loc[row_name, 'f1_score'] = 0.696255

# %% [markdown]
# A compressed BERT model using tensor networks (tn_bert)

# %%
# A compressed BERT model using tensor networks (tn_bert)
df_with_all_models.loc['Compressed BERT model using tensor networks'] = ' ' 
# first
row_name = 'tn_bert trained on hotel reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.864483
df_with_all_models.loc[row_name, 'precision'] = 0.880075
df_with_all_models.loc[row_name, 'recall'] = 0.833775
df_with_all_models.loc[row_name, 'f1_score'] = 0.8563
# second
row_name = 'tn_bert trained on hotel reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7162
df_with_all_models.loc[row_name, 'precision'] = 0.735102
df_with_all_models.loc[row_name, 'recall'] = 0.676
df_with_all_models.loc[row_name, 'f1_score'] = 0.704313
# third
row_name = 'tn_bert trained on movie reviews and tested on hotel reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.85228
df_with_all_models.loc[row_name, 'precision'] = 0.821078
df_with_all_models.loc[row_name, 'recall'] = 0.888594
df_with_all_models.loc[row_name, 'f1_score'] = 0.853503
# fourth
row_name = 'tn_bert trained on movie reviews and tested on movie reviews dataset'
df_with_all_models.loc[row_name, 'accuracy'] = 0.7614
df_with_all_models.loc[row_name, 'precision'] = 0.752025
df_with_all_models.loc[row_name, 'recall'] = 0.78
df_with_all_models.loc[row_name, 'f1_score'] = 0.765757

# %% [markdown]
# Образец ниже (закомментированный код)

# %%
# # MODEL_NAME
# df_with_all_models.loc['MODEL_NAME'] = ' ' 
# # first
# row_name = 
# df_with_all_models.loc[row_name, 'accuracy'] = 
# df_with_all_models.loc[row_name, 'precision'] = 
# df_with_all_models.loc[row_name, 'recall'] = 
# df_with_all_models.loc[row_name, 'f1_score'] = 
# # second
# row_name = 
# df_with_all_models.loc[row_name, 'accuracy'] = 
# df_with_all_models.loc[row_name, 'precision'] = 
# df_with_all_models.loc[row_name, 'recall'] = 
# df_with_all_models.loc[row_name, 'f1_score'] = 
# # third
# row_name = 
# df_with_all_models.loc[row_name, 'accuracy'] = 
# df_with_all_models.loc[row_name, 'precision'] = 
# df_with_all_models.loc[row_name, 'recall'] = 
# df_with_all_models.loc[row_name, 'f1_score'] = 
# # fourth
# row_name = 
# df_with_all_models.loc[row_name, 'accuracy'] = 
# df_with_all_models.loc[row_name, 'precision'] = 
# df_with_all_models.loc[row_name, 'recall'] = 
# df_with_all_models.loc[row_name, 'f1_score'] =

# %% [markdown]
# **Итог**

# %%
df_with_all_models
# Out:
#                                                     accuracy precision  \
# ALBERT
# albert trained on hotel reviews and tested on h...  0.757868   0.83964
# albert trained on hotel reviews and tested on m...    0.5752  0.693416
# albert trained on movie reviews and tested on h...  0.640334  0.843972
# albert trained on movie reviews and tested on m...     0.695   0.68991
# BERT
# bert trained on hotel reviews and tested on hot...  0.746735  0.706468
# bert trained on hotel reviews and tested on mov...    0.5542  0.531071
# bert trained on movie reviews and tested on hot...  0.761507  0.733333
# bert trained on movie reviews and tested on mov...    0.6868  0.732802
# DistilBERT
# distilbert trained on hotel reviews and tested ...  0.873261  0.900288
# distilbert trained on hotel reviews and tested ...    0.7198  0.819663
# distilbert trained on movie reviews and tested ...  0.782916  0.695244
# distilbert trained on movie reviews and tested ...    0.7728  0.803381
# ELECTRA
# ...

# %% [markdown]
# # Теперь визуализируем данные

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

# %matplotlib inline

np.random.seed(191)

# %config InlineBackend.figure_format = 'retina'

# sns.set(style='whitegrid', palette='deep')
# sns.set(style='darkgrid', palette='rocket')
sns.set(style='darkgrid', palette='deep')

plt.rcParams['figure.figsize'] = 14, 9
plt.rcParams['font.size'] = 12
plt.rcParams['savefig.format'] = 'pdf'

# %%
# model_names = ['ALBERT', 'BERT', 'DistilBERT', 'ELECTRA', 'LaBSE',
#                'LAMBERT', 'MobileBERT', 'ROBERTA', 'BERT with Talking-Heads Attention and Gated GELU', 'Compressed BERT model using tensor networks']
model_names = ['ALBERT', 'BERT', 'DistilBERT', 'ELECTRA', 'LaBSE',
               'LAMBERT', 'MobileBERT', 'ROBERTA', 'talkheads_ggelu_bert', 'tn_bert']

# %% [markdown]
# Визуализируем
#
# trained on hotel reviews and tested on hotel reviews dataset

# %%
dataset_names = ['hotel', 'movie']

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 11))
for i in range(2):
    for j in range(2):
        df_cur = df_with_all_models[df_with_all_models.index.str.contains('trained on ' + dataset_names[i] +
                                                                          ' reviews and tested on ' + dataset_names[j] + ' reviews dataset') == True]
        axes[i, j].scatter(x=model_names, y=df_cur.accuracy, label='accuracy', marker='x', s=170)
        axes[i, j].scatter(x=model_names, y=df_cur.precision, label='precision', marker='s', s=100)
        axes[i, j].scatter(x=model_names, y=df_cur.recall, label='recall', marker='^', s=100)
        axes[i, j].scatter(x=model_names, y=df_cur.f1_score, label='f1_score', s=100)
        axes[i, j].set_title("Results for 10 models "
         + 'trained on ' + dataset_names[i] +' reviews and tested on ' 
         + dataset_names[j] + ' reviews dataset', fontsize=14)
        axes[i, j].tick_params(axis='x', labelrotation = 35)
        axes[i, j].legend()
fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 11))
for i in range(2):
    for j in range(2):
        df_cur = df_with_all_models[df_with_all_models.index.str.contains('trained on ' + dataset_names[i] +
                                                                          ' reviews and tested on ' + dataset_names[j] + ' reviews dataset') == True]
        axes[i, j].scatter(x=['accuracy'] * len(df_cur.accuracy), y=df_cur.accuracy)
        axes[i, j].scatter(x=['precision'] * len(df_cur.precision), y=df_cur.precision)
        axes[i, j].scatter(x=['recall'] * len(df_cur.recall), y=df_cur.recall)
        axes[i, j].scatter(x=['f1_score'] * len(df_cur.f1_score), y=df_cur.f1_score)
        axes[i, j].scatter(x=['accuracy', 'precision', 'recall', 'f1_score'], 
                           y=[df_cur.accuracy.mean(), df_cur.precision.mean(), df_cur.recall.mean(), df_cur.f1_score.mean()],
                           color='blue', marker='s', s=100, label='Mean value')
        axes[i, j].scatter(x=['accuracy', 'precision', 'recall', 'f1_score'], 
                    y=[df_cur.accuracy.median(), df_cur.precision.median(), df_cur.recall.median(), df_cur.f1_score.median()],
                    color='black', marker='x', s=150, label='Median value')
        axes[i, j].set_title("Accuracy, precision, recall and f1_score for all models " 
                             +'trained on ' + dataset_names[i] +' reviews and tested on '
                              + dataset_names[j] + ' reviews dataset', fontsize=10)
        axes[i, j].legend()
fig.tight_layout()

plt.show()
